# %%
import pandas as pd
import numpy as np
import seaborn as sns

data = pd.read_csv("./tracked.csv")

t = data['time'][0:300]
y1 = data['y1'][0:300]
y2 = data['y2'][0:300]
e1 = data['e1'][0:300]
e2 = data['e2'][0:300]
p1 = data['p1'][0:300]
p2 = data['p2'][0:300]


data.head()

sns.histplot(data=data, x="y1")

# %%
sns.histplot(data=data, x="y2")

# %%
sns.histplot(data=data, x="e1")

# %%
sns.histplot(data=data, x="e2")

# %%
d = data.iloc[3476:3494,:]
sns.scatterplot(data=d, x="time", y="e2")
sns.scatterplot(data=d, x="time", y="y2")

# %%
data.iloc[3487]
# Out:
# time           212
# y1         2.49041
# y2         1.59708
# e1      0.00249146
# e2         1.01124
# p1       0.0748412
# p2        0.925158
# Name: 3487, dtype: object

# %%
sns.scatterplot(data = data.iloc[3400: 3705], x='time', y='p2')
sns.scatterplot(data = data.iloc[3400: 3705], x='time', y='p1')

# %%
sns.scatterplot(data = data.iloc[3400: 3705], x='time', y='y2')
#sns.scatterplot(data = data.iloc[3400: 3705], x='time', y='p1')

# %%
sns.histplot(data = data.iloc[3400: 3705], x='e1')

# %%
sns.histplot(data = data.iloc[3400: 3705], x='e2')
